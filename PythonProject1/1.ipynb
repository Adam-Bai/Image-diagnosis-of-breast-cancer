# %%
sub = {
    "breakhis":  ("BreaKHis", ["breakhis","BreaKHis"]),
    "cbis_ddsm": ("CBIS_DDSM", ["cbis_ddsm","CBIS-DDSM","cbis"]),
    "inbreast":  ("INbreast", ["inbreast","INbreast"]),
    "wbcd":      ("WBCD", ["wbcd","WDBC"]),
    "busi":      ("BUSI", ["busi","BUSI","Dataset_BUSI_with_GT"]),
    "duke_mri":  ("DukeMRI", ["duke","duke_mri"]),
    "i_spy1":    ("I_SPY1", ["i_spy1","ISPY1"]),
    "i_spy2":    ("I_SPY2", ["i_spy2","ISPY2"]),
    "us_b":      ("US_B", ["us_b","ultrasound_b"]),
}

# %%
from dotenv import load_dotenv, find_dotenv
load_dotenv(find_dotenv(), override=False)
# Out:
# False

# %%
from pathlib import Path
from dotenv import load_dotenv, find_dotenv
print("found:", find_dotenv())              # 看看能不能找到；找不到会是空字符串
load_dotenv(Path.cwd() / ".env", override=False)  # 以“当前工作目录”为准
# Out:
# found:
# False

# %%
import os
print(os.getenv("DATA_ROOT"))
print(os.getenv("DATASETS_READY"))
# Out:
# None
# None

# %%
from pathlib import Path
from dotenv import load_dotenv
ENV_PATH = Path(__file__).resolve().parent / ".env"   # 和脚本一个目录
print("env file ->", ENV_PATH, ENV_PATH.exists())
load_dotenv(ENV_PATH, override=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 from pathlib import Path
#       2 from dotenv import load_dotenv
# ----> 3 ENV_PATH = Path(__file__).resolve().parent / ".env"   # 和脚本一个目录
#       4 print("env file ->", ENV_PATH, ENV_PATH.exists())
#       5 load_dotenv(ENV_PATH, override=False)
#
# NameError: name '__file__' is not defined

# %%
from dotenv import load_dotenv
load_dotenv("/Users/Zhuanz/PythonProject1.env", override=False)
ls -la "/Users/Zhuanz/PythonProject1/.env"
# Out:
# False

# %%
from pathlib import Path
from dotenv import load_dotenv

env_path = Path("/.env")  # 正确路径
print("env exists:", env_path.exists(), env_path)     # 应该 True
ok = load_dotenv(env_path, override=False)
print("loaded:", ok)
# Out:
# env exists: True /Users/Zhuanz/PythonProject1/.env
# loaded: True

# %%
import os
print("DATA_ROOT =", os.getenv("DATA_ROOT"))
print("DATASETS_READY =", os.getenv("DATASETS_READY"))
# Out:
# DATA_ROOT = /Users/Zhuanz/Desktop/breastcancer/data
# DATASETS_READY = BreaKHis,CBIS_DDSM,INbreast,WBCD,BUSI,METABRIC,TCGA_BRCA
